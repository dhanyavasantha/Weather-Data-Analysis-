# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
data = pd.read_csv("weatherHistory.csv")

# %%
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
data = data.dropna()

# %%
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'])

# %%
data = data.drop_duplicates()

# %%
data = data.drop(columns=['Loud Cover'])

# %%
data
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01 00:00:00+02:00  Partly Cloudy        rain         9.472222
# 1      2006-04-01 01:00:00+02:00  Partly Cloudy        rain         9.355556
# 2      2006-04-01 02:00:00+02:00  Mostly Cloudy        rain         9.377778
# 3      2006-04-01 03:00:00+02:00  Partly Cloudy        rain         8.288889
# 4      2006-04-01 04:00:00+02:00  Mostly Cloudy        rain         8.755556
# ...                          ...            ...         ...              ...
# 96448  2016-09-09 19:00:00+02:00  Partly Cloudy        rain        26.016667
# 96449  2016-09-09 20:00:00+02:00  Partly Cloudy        rain        24.583333
# 96450  2016-09-09 21:00:00+02:00  Partly Cloudy        rain        22.038889
# 96451  2016-09-09 22:00:00+02:00  Partly Cloudy        rain        21.522222
# 96452  2016-09-09 23:00:00+02:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     95912.000000              95912.000000  95912.000000
# mean         11.937975                 10.859194      0.734844
# std           9.569620                 10.716711      0.195717
# min         -21.822222                -27.716667      0.000000
# 25%           4.594444                  2.272222      0.600000
# 50%          12.022222                 12.022222      0.780000
# 75%          18.844444                 18.844444      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count       95912.000000            95912.000000     95912.000000
# mean           10.806764              187.506986        10.362306
# std             6.920504              107.378309         4.174204
# min             0.000000                0.000000         0.000000
# ...

# %%
data.to_csv("weather_data.csv", index=False)

# %%
# Plotting temperature over time
plt.figure(figsize=(10, 6))
plt.plot(data['Formatted Date'], data['Temperature (C)'], color='blue')
plt.title('Temperature Variation Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (C)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting humidity over time
plt.figure(figsize=(10, 6))
plt.plot(data['Formatted Date'], data['Humidity'], color='green')
plt.title('Humidity Variation Over Time')
plt.xlabel('Date')
plt.ylabel('Humidity')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting pressure over time
plt.figure(figsize=(10, 6))
plt.plot(data['Formatted Date'], data['Pressure (millibars)'], color='red')
plt.title('Pressure Variation Over Time')
plt.xlabel('Date')
plt.ylabel('Pressure (millibars)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Get unique values of the 'Daily Summary' column
unique_summaries = data['Summary'].unique()

# Print the unique values
print(unique_summaries)
print(len(unique_summaries))
# Out:
# ['Partly Cloudy' 'Mostly Cloudy' 'Overcast' 'Foggy'
#  'Breezy and Mostly Cloudy' 'Clear' 'Breezy and Partly Cloudy'
#  'Breezy and Overcast' 'Humid and Mostly Cloudy' 'Humid and Partly Cloudy'
#  'Windy and Foggy' 'Windy and Overcast' 'Breezy and Foggy'
#  'Windy and Partly Cloudy' 'Breezy' 'Dry and Partly Cloudy'
#  'Windy and Mostly Cloudy' 'Dangerously Windy and Partly Cloudy' 'Dry'
#  'Windy' 'Humid and Overcast' 'Light Rain' 'Drizzle' 'Windy and Dry'
#  'Dry and Mostly Cloudy' 'Breezy and Dry' 'Rain']
# 27

# %%
summary_temp = data.groupby('Summary')['Temperature (C)'].mean().reset_index()
# Plotting summary vs. mean temperature
plt.figure(figsize=(12, 6))
plt.bar(summary_temp['Summary'], summary_temp['Temperature (C)'], color='red')
plt.title('Mean Temperature for Each Summary')
plt.xlabel('Summary')
plt.ylabel('Mean Temperature (C)')
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()
plt.show()

# %%
summary_hum = data.groupby('Summary')['Humidity'].mean().reset_index()
# Plotting summary vs. mean temperature
plt.figure(figsize=(12, 6))
plt.bar(summary_hum['Summary'], summary_hum['Humidity'], color='red')
plt.title('Mean Humidity for Each Summary')
plt.xlabel('Summary')
plt.ylabel('Mean Temperature (C)')
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()
plt.show()
